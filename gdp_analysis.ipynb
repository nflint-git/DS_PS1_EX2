# %%
from pys.data import load_dataset

# %%
dataframe = load_dataset("GDP.csv")
# Out:
# c:\Users\Asus\OneDrive - University of Cambridge\Desktop\Cambridge\D100 Data Science\Clone\DS_PS1_EX2-2\pys\data.py:17: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   filtered_df = filtered_df.applymap(round_to_nearest_billion)

# %%
dataframe
# Out:
#                 2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# Country
# Switzerland      279   287   309   362   404   418   442   491   567   554
# China           1211  1339  1471  1660  1955  2286  2752  3550  4594  5102
# Germany         1948  1946  2078  2502  2814  2847  2995  3426  3745  3411
# United Kingdom  1666  1649  1786  2057  2423  2545  2710  3093  2932  2418
# Japan           4968  4375  4183  4520  4893  4831  4602  4580  5107  5289
#
#                 ...  2013   2014   2015   2016   2017   2018   2019   2020  \
# Country         ...
# Switzerland     ...   706    727    694    688    695    726    721    740
# China           ...  9570  10476  11062  11233  12310  13895  14280  14688
# Germany         ...  3734   3889   3358   3470   3691   3974   3888   3890
# United Kingdom  ...  2786   3065   2935   2700   2683   2878   2857   2705
# Japan           ...  5212   4897   4445   5004   4931   5041   5118   5049
#
#                  2021   2022
# ...

# %%
from pys.plot_utilis import plotting

# %%
plotting(dataframe)
